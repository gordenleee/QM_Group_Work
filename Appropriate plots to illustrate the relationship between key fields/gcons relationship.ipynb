# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#read csv
data = pd.read_csv("./processed_data.csv")

# %%
#PROP_TYPE

# select PROP_TYPE
prop_types = data['PROP_TYPE'].unique()

# sreate plot
fig, axes = plt.subplots(nrows=len(prop_types), ncols=1, figsize=(8, 8), sharex=True)

# histograms
for prop_type, ax in zip(prop_types, axes):
    subset = data[data['PROP_TYPE'] == prop_type]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 6000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PROP_TYPE and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
#PROP_TYPE

# select PROP_TYPE
prop_types = data['PROP_TYPE'].unique()

# sreate plot
fig, axes = plt.subplots(nrows=len(prop_types), ncols=1, figsize=(8, 8), sharex=True)

# histograms
for prop_type, ax in zip(prop_types, axes):
    subset = data[data['PROP_TYPE'] == prop_type]
    # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 6000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PROP_TYPE and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3327676701.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3327676701.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3327676701.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select PROP_AGE_BAND
prop_age_bands = data['PROP_AGE_BAND'].unique()

# Sort PROP_AGE_BAND in ascending order
prop_age_bands = sorted(prop_age_bands)

# create plot
fig, axes = plt.subplots(nrows=len(prop_age_bands), ncols=1, figsize=(8, 6), sharex=True)

# histograms
for prop_age_band, ax in zip(prop_age_bands, axes):
    subset = data[data['PROP_AGE_BAND'] == prop_age_band]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_age_band)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 4000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PROP_AGE_BAND and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select PROP_AGE_BAND
prop_age_bands = data['PROP_AGE_BAND'].unique()

# Sort PROP_AGE_BAND in ascending order
prop_age_bands = sorted(prop_age_bands)

# create plot
fig, axes = plt.subplots(nrows=len(prop_age_bands), ncols=1, figsize=(8, 6), sharex=True)

# histograms
for prop_age_band, ax in zip(prop_age_bands, axes):
    subset = data[data['PROP_AGE_BAND'] == prop_age_band]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 8000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PROP_AGE_BAND and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3741377339.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3741377339.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3741377339.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select FLOOR_AREA_BAND
floor_area_bands = data['FLOOR_AREA_BAND'].unique()

# Sort FLOOR_AREA_BAND in ascending order
floor_area_bands = sorted(floor_area_bands)

# create plot
fig, axes = plt.subplots(nrows=len(floor_area_bands), ncols=1, figsize=(8, 13), sharex=True)

# histograms
for floor_area_band, ax in zip(floor_area_bands, axes):
    subset = data[data['FLOOR_AREA_BAND'] == floor_area_band]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=floor_area_band)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 5000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between FLOOR_AREA_BAND and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select FLOOR_AREA_BAND
floor_area_bands = data['FLOOR_AREA_BAND'].unique()

# Sort FLOOR_AREA_BAND in ascending order
floor_area_bands = sorted(floor_area_bands)

# create plot
fig, axes = plt.subplots(nrows=len(floor_area_bands), ncols=1, figsize=(8, 13), sharex=True)

# histograms
for floor_area_band, ax in zip(floor_area_bands, axes):
    subset = data[data['FLOOR_AREA_BAND'] == floor_area_band]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)
    # Set y-axis range for each subplot
    ax.set_ylim(0, 10000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between FLOOR_AREA_BAND and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/2301560284.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/2301560284.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/2301560284.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select COUNCIL_TAX_BAND
council_tax_bands = data['COUNCIL_TAX_BAND'].unique()

# Sort COUNCIL_TAX_BAND in the desired order (A-H)
council_tax_bands = sorted(council_tax_bands, key=lambda x: ord(x))

# create plot
fig, axes = plt.subplots(nrows=len(council_tax_bands), ncols=1, figsize=(8, 12), sharex=True)

# histograms
for council_tax_band, ax in zip(council_tax_bands, axes):
    subset = data[data['COUNCIL_TAX_BAND'] == council_tax_band]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=council_tax_band)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 3000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between COUNCIL_TAX_BAND and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select COUNCIL_TAX_BAND
council_tax_bands = data['COUNCIL_TAX_BAND'].unique()

# Sort COUNCIL_TAX_BAND in the desired order (A-H)
council_tax_bands = sorted(council_tax_bands, key=lambda x: ord(x))

# create plot
fig, axes = plt.subplots(nrows=len(council_tax_bands), ncols=1, figsize=(8, 12), sharex=True)

# histograms
for council_tax_band, ax in zip(council_tax_bands, axes):
    subset = data[data['COUNCIL_TAX_BAND'] == council_tax_band]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 6000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between COUNCIL_TAX_BAND and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/2794268268.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/2794268268.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/2794268268.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select IMD_BAND_ENG
imd_bands = data['IMD_BAND_ENG'].unique()

# Sort IMD_BAND_ENG in ascending order
imd_bands = sorted(imd_bands)

# create plot
fig, axes = plt.subplots(nrows=len(imd_bands), ncols=1, figsize=(8, 6), sharex=True)

# histograms
for imd_band, ax in zip(imd_bands, axes):
    subset = data[data['IMD_BAND_ENG'] == imd_band]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=imd_band)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 3000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between IMD_BAND_ENG and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select IMD_BAND_ENG
imd_bands = data['IMD_BAND_ENG'].unique()

# Sort IMD_BAND_ENG in ascending order
imd_bands = sorted(imd_bands)

# create plot
fig, axes = plt.subplots(nrows=len(imd_bands), ncols=1, figsize=(8, 6), sharex=True)

# histograms
for imd_band, ax in zip(imd_bands, axes):
    subset = data[data['IMD_BAND_ENG'] == imd_band]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 6000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between IMD_BAND_ENG and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/1657902197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/1657902197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/1657902197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select REGION
regions = data['REGION'].unique()

# Sort REGION in ascending order
regions = sorted(regions)

# create plot
fig, axes = plt.subplots(nrows=len(regions), ncols=1, figsize=(8, 12), sharex=True)

# histograms
for region, ax in zip(regions, axes):
    subset = data[data['REGION'] == region]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=region)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 2000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between REGION and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select REGION
regions = data['REGION'].unique()

# Sort REGION in ascending order
regions = sorted(regions)

# create plot
fig, axes = plt.subplots(nrows=len(regions), ncols=1, figsize=(8, 12), sharex=True)

# histograms
for region, ax in zip(regions, axes):
    subset = data[data['REGION'] == region]
    # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 3000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between REGION and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3197474348.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3197474348.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3197474348.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# select LI_FLAG
li_flags = data['LI_FLAG'].unique()

# Sort LI_FLAG
li_flags = sorted(li_flags)

# create plot
fig, axes = plt.subplots(nrows=len(li_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for li_flag, ax in zip(li_flags, axes):
    subset = data[data['LI_FLAG'] == li_flag]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=li_flag)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 10000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between LI_FLAG and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select LI_FLAG
li_flags = data['LI_FLAG'].unique()

# Sort LI_FLAG
li_flags = sorted(li_flags)

# create plot
fig, axes = plt.subplots(nrows=len(li_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for li_flag, ax in zip(li_flags, axes):
    subset = data[data['LI_FLAG'] == li_flag]
    # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 16000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between LI_FLAG and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3781141741.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3781141741.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)

# %%
# select CWI_FLAG
cwi_flags = data['CWI_FLAG'].unique()

# Sort CWI_FLAG 
cwi_flags = sorted(cwi_flags)

# create plot
fig, axes = plt.subplots(nrows=len(cwi_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for cwi_flag, ax in zip(cwi_flags, axes):
    subset = data[data['CWI_FLAG'] == cwi_flag]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=cwi_flag)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 10000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between CWI_FLAG and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select CWI_FLAG
cwi_flags = data['CWI_FLAG'].unique()

# Sort CWI_FLAG 
cwi_flags = sorted(cwi_flags)

# create plot
fig, axes = plt.subplots(nrows=len(cwi_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for cwi_flag, ax in zip(cwi_flags, axes):
    subset = data[data['CWI_FLAG'] == cwi_flag]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 16000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between CWI_FLAG and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3232366891.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3232366891.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)

# %%
# select PV_FLAG
pv_flags = data['PV_FLAG'].unique()

# Sort PV_FLAG 
pv_flags = sorted(pv_flags)

# create plot
fig, axes = plt.subplots(nrows=len(pv_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for pv_flag, ax in zip(pv_flags, axes):
    subset = data[data['PV_FLAG'] == pv_flag]
    subset['Gcons2019'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=pv_flag)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 10000)
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PV_FLAG and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select PV_FLAG
pv_flags = data['PV_FLAG'].unique()

# Sort PV_FLAG 
pv_flags = sorted(pv_flags)

# create plot
fig, axes = plt.subplots(nrows=len(pv_flags), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for pv_flag, ax in zip(pv_flags, axes):
    subset = data[data['PV_FLAG'] == pv_flag]
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    
    
    ax.legend()  # add legends for the small figures

# set the title and axis labels
plt.suptitle("Relationship between PV_FLAG and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/3057489867.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/3057489867.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)

# %%
# select MAIN_HEAT_FUEL
main_heat_fuels = data['MAIN_HEAT_FUEL'].unique()

# Sort MAIN_HEAT_FUEL
main_heat_fuels = sorted(main_heat_fuels)

# Determine the global bin edges based on the maximum range of Gcons2019
global_bins = range(0, int(data['Gcons2019'].max()) + 1000, 1000)

# create plot
fig, axes = plt.subplots(nrows=len(main_heat_fuels), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for main_heat_fuel, ax in zip(main_heat_fuels, axes):
    subset = data[data['MAIN_HEAT_FUEL'] == main_heat_fuel]
 
    subset['Gcons2019'].plot(kind='hist', bins=global_bins, color='steelblue', alpha=0.7, ax=ax, label=main_heat_fuel)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 10000)
    ax.legend()

# set the title and axis labels
plt.suptitle("Relationship between MAIN_HEAT_FUEL and Gcons2019", y=1)
plt.xlabel("Annual gas consumption/ kWh")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()

# %%
# select MAIN_HEAT_FUEL
main_heat_fuels = data['MAIN_HEAT_FUEL'].unique()

# Sort MAIN_HEAT_FUEL
main_heat_fuels = sorted(main_heat_fuels)

# Determine the global bin edges based on the maximum range of Gcons2019
global_bins = range(0, int(data['Gcons2019'].max()) + 1000, 1000)

# create plot
fig, axes = plt.subplots(nrows=len(main_heat_fuels), ncols=1, figsize=(8, 3), sharex=True)

# histograms
for main_heat_fuel, ax in zip(main_heat_fuels, axes):
    subset = data[data['MAIN_HEAT_FUEL'] == main_heat_fuel]
 
     # Apply log transformation with a minimum value
    subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
    
    subset['Gcons2019_log'].plot(kind='hist', bins=20, color='steelblue', alpha=0.7, ax=ax, label=prop_type)

    # Set y-axis range for each subplot
    ax.set_ylim(0, 20000)
    ax.legend()

# set the title and axis labels
plt.suptitle("Relationship between MAIN_HEAT_FUEL and Gcons2019(Log Scale)", y=1)
plt.xlabel("Log of Annual gas consumption")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_122/4289481582.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)
# /tmp/ipykernel_122/4289481582.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Gcons2019_log'] = subset['Gcons2019'].apply(lambda x: np.log1p(x) if x > 0 else 0)

# %%
#LinearRegression

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import seaborn as sns

# %%
# read csv
data_lr = pd.read_csv("./processed_data2.csv")

# %%
# Make sure the required columns exist
if 'PROP_AGE_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['PROP_AGE_BAND']]
y = data_lr['Gcons2019']

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['PROP_AGE_BAND']]
y_sampled = sampled_data['Gcons2019']

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()

# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['PROP_AGE_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['PROP_AGE_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['PROP_AGE_BAND']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('PROP_AGE_BAND')
plt.ylabel('Gcons2019/ kwh')
plt.title('Linear Regression(PROP_AGE_BAND and Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     362.6
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           5.21e-79
# Time:                        13:51:14   Log-Likelihood:                -78835.
# No. Observations:                7573   AIC:                         1.577e+05
# Df Residuals:                    7571   BIC:                         1.577e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.504e+04    231.115     65.062      0.000    1.46e+04    1.55e+04
# ...

# %%
# Make sure the required columns exist
if 'PROP_AGE_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['PROP_AGE_BAND']]
y = np.log1p(data_lr['Gcons2019'])

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['PROP_AGE_BAND']]
y_sampled = np.log1p(sampled_data['Gcons2019'])

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()

# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['PROP_AGE_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['PROP_AGE_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['PROP_AGE_BAND']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('PROP_AGE_BAND')
plt.ylabel('Log of Gcons2019')
plt.title('Linear Regression(PROP_AGE_BAND and Log of Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     234.5
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           3.80e-52
# Time:                        14:24:09   Log-Likelihood:                -20136.
# No. Observations:                7573   AIC:                         4.028e+04
# Df Residuals:                    7571   BIC:                         4.029e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             9.1784      0.099     92.309      0.000       8.983       9.373
# ...

# %%
# Make sure the required columns exist
if 'FLOOR_AREA_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['FLOOR_AREA_BAND']]
y = data_lr['Gcons2019']

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['FLOOR_AREA_BAND']]
y_sampled = sampled_data['Gcons2019']

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()
# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['FLOOR_AREA_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['FLOOR_AREA_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['FLOOR_AREA_BAND']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('FLOOR_AREA_BAND')
plt.ylabel('Gcons2019/ kwh')
plt.title('Linear Regression(FLOOR_AREA_BAND and Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.182
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     1685.
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):               0.00
# Time:                        15:40:33   Log-Likelihood:                -78252.
# No. Observations:                7573   AIC:                         1.565e+05
# Df Residuals:                    7571   BIC:                         1.565e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2075.1247    233.661      8.881      0.000    1617.084    2533.165
# ...

# %%
# Make sure the required columns exist
if 'FLOOR_AREA_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['FLOOR_AREA_BAND']]
y = np.log1p(data_lr['Gcons2019'])

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['FLOOR_AREA_BAND']]
y_sampled = np.log1p(sampled_data['Gcons2019'])

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()
# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['FLOOR_AREA_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['FLOOR_AREA_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['FLOOR_AREA_BAND']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('FLOOR_AREA_BAND')
plt.ylabel('Log of Gcons2019')
plt.title('Linear Regression(FLOOR_AREA_BAND and Log of Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     404.6
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           1.03e-87
# Time:                        14:27:42   Log-Likelihood:                -20054.
# No. Observations:                7573   AIC:                         4.011e+04
# Df Residuals:                    7571   BIC:                         4.013e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               5.7715      0.107     53.730      0.000       5.561       5.982
# ...

# %%
# Make sure the required columns exist
if 'COUNCIL_TAX_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['COUNCIL_TAX_BAND']]
y = data_lr['Gcons2019']

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['COUNCIL_TAX_BAND']]
y_sampled = sampled_data['Gcons2019']

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()
# Output regression results, including p-values
print(model.summary())
# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['COUNCIL_TAX_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['COUNCIL_TAX_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['COUNCIL_TAX_BAND'], y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('COUNCIL_TAX_BAND')
plt.ylabel('Gcons2019/ kwh')
plt.title('Linear Regression(COUNCIL_TAX_BAND and Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     713.8
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):          2.39e-150
# Time:                        15:40:55   Log-Likelihood:                -78671.
# No. Observations:                7573   AIC:                         1.573e+05
# Df Residuals:                    7571   BIC:                         1.574e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             8148.9545    139.869     58.261      0.000    7874.773    8423.136
# ...

# %%
# Make sure the required columns exist
if 'COUNCIL_TAX_BAND' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['COUNCIL_TAX_BAND']]
y = np.log1p(data_lr['Gcons2019'])

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['COUNCIL_TAX_BAND']]
y_sampled = np.log1p(sampled_data['Gcons2019'])

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()
# Output regression results, including p-values
print(model.summary())
# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter

plt.scatter(X_test['COUNCIL_TAX_BAND']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)  
sns.stripplot(x=X_test['COUNCIL_TAX_BAND'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['COUNCIL_TAX_BAND'], y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('COUNCIL_TAX_BAND')
plt.ylabel('Log of Gcons2019')
plt.title('Linear Regression(COUNCIL_TAX_BAND and Log of Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.696
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):             0.0303
# Time:                        14:26:13   Log-Likelihood:                -20249.
# No. Observations:                7573   AIC:                         4.050e+04
# Df Residuals:                    7571   BIC:                         4.052e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                7.6793      0.062    123.030      0.000       7.557       7.802
# ...

# %%
# Make sure the required columns exist
if 'IMD_BAND_ENG' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['IMD_BAND_ENG']]
y = data_lr['Gcons2019']

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['IMD_BAND_ENG']]
y_sampled = sampled_data['Gcons2019']

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()

# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter
plt.scatter(X_test['IMD_BAND_ENG']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)
sns.stripplot(x=X_test['IMD_BAND_ENG'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['IMD_BAND_ENG']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('IMD_BAND_ENG')
plt.ylabel('Gcons2019/ kwh')
plt.title('Linear Regression(IMD_BAND_ENG and Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     241.7
# Date:                Sat, 02 Dec 2023   Prob (F-statistic):           1.13e-53
# Time:                        15:41:54   Log-Likelihood:                -78894.
# No. Observations:                7573   AIC:                         1.578e+05
# Df Residuals:                    7571   BIC:                         1.578e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         8002.3403    214.204     37.359      0.000    7582.442    8422.239
# ...

# %%
# Make sure the required columns exist
if 'IMD_BAND_ENG' not in data_lr.columns or 'Gcons2019' not in data_lr.columns:
    print("Required columns not found in the dataset.")
    exit()

# Extract features (independent variables) and targets (dependent variables)
X = data_lr[['IMD_BAND_ENG']]
y = np.log1p(data_lr['Gcons2019'])

# Sample the data
sampled_data = data_lr.sample(frac=0.2, random_state=42)  

# Extract the sampled features and targets
X_sampled = sampled_data[['IMD_BAND_ENG']]
y_sampled = np.log1p(sampled_data['Gcons2019'])

# Divide the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, test_size=0.2, random_state=42)

# Add a constant column
X_train = sm.add_constant(X_train)

# Create a linear regression model
model = sm.OLS(y_train, X_train).fit()

# Output regression results, including p-values
print(model.summary())

# Make predictions on the test set
X_test = sm.add_constant(X_test)
y_pred = model.predict(X_test)

# Calculating the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print mean squared error
print("Mean Squared Error:", mse)

# Draw scatter plots and fitted straight lines, adding random jitter
plt.scatter(X_test['IMD_BAND_ENG']-1, y_test, color='black', label='Actual data points', alpha=0.5, s=1.8)
sns.stripplot(x=X_test['IMD_BAND_ENG'], y=y_test, jitter=True, color='blue', size=1.8, alpha=0.3, label='Jittered points')
plt.plot(X_test['IMD_BAND_ENG']-1, y_pred, color='red', linewidth=3, label='Linear Regression Fit')

plt.xlabel('IMD_BAND_ENG')
plt.ylabel('Log of Gcons2019')
plt.title('Linear Regression(IMD_BAND_ENG and Log of Gcons2019) with Sampled Data and Jittered Points')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Gcons2019   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     21.91
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):           2.90e-06
# Time:                        14:27:15   Log-Likelihood:                -20240.
# No. Observations:                7573   AIC:                         4.048e+04
# Df Residuals:                    7571   BIC:                         4.050e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            7.3915      0.093     79.718      0.000       7.210       7.573
# ...
