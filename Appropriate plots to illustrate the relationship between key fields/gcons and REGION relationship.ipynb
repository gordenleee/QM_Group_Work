# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read csv
data = pd.read_csv("./processed_data.csv")

# %%
#REGION E12000001
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000001"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000001, North East)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000002
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000002"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000002, North West)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000003
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000003"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000003, Yorkshire and The Humber)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000004
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000004"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000004, East Midlands)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000005
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000005"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000005, West Midlands)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000006
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000006"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000006, East)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000007
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000007"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000007, London)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000008
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000008"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000008, South East)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()

# %%
#REGION E12000009
# select the column
columns_to_plot = ["Gcons2005", "Gcons2006", "Gcons2007", "Gcons2008", "Gcons2009", "Gcons2010", "Gcons2011",
                   "Gcons2012", "Gcons2013", "Gcons2014", "Gcons2015", "Gcons2016", "Gcons2017", "Gcons2018", "Gcons2019"]

# select data
selected_data = data[data["REGION_E12000009"].isin([1])]

# sreate plot
fig, axs = plt.subplots(len(columns_to_plot), 1, figsize=(10, 16), sharex=True)

# histograms
for i, column in enumerate(columns_to_plot):
    data_to_plot = selected_data[column]
    bins = 20  
    
    axs[i].hist(data_to_plot, bins=bins, color=f'C{i}', edgecolor="black", alpha=0.5, label=column)
  
    # add legends for the small figures
    axs[i].legend()

# set the title and axis labels
plt.suptitle("Histograms of Gcons2005-2019 (REGION=E12000009, South West)", y=0.95)
plt.xlabel("Annual gas consumption (kWh)")
plt.ylabel("Frequency")

# adjust the layout
plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # leave space for the years

# show plot
plt.show()
